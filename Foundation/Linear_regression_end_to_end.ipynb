# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhaveffai/pytorch-learning/blob/main/week1/Linear_regression_end_to_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

X = torch.linspace(0, 10, 20).unsqueeze(1)
y = 5 * X + 10 + 0.1 * torch.randn(20,1)

model = nn.Sequential(nn.Linear(1,1))
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

for epoch in range(1000):
  y_pred = model(X)
  loss = loss_fn(y_pred, y)

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if epoch %10 == 0:
    print(f"Epoch {epoch} | Loss {loss.item():.4f}")

print(f"Learned Weight:{model[0].weight.data.item()}, Learned Bias :{model[0].bias.data.item()}")
# Out:
# Epoch 0 | Loss 1605.3109
# Epoch 10 | Loss 22.1729
# Epoch 20 | Loss 19.9498
# Epoch 30 | Loss 17.9497
# Epoch 40 | Loss 16.1502
# Epoch 50 | Loss 14.5312
# Epoch 60 | Loss 13.0746
# Epoch 70 | Loss 11.7641
# Epoch 80 | Loss 10.5851
# Epoch 90 | Loss 9.5243
# Epoch 100 | Loss 8.5700
# Epoch 110 | Loss 7.7114
# Epoch 120 | Loss 6.9388
# Epoch 130 | Loss 6.2438
# Epoch 140 | Loss 5.6185
# Epoch 150 | Loss 5.0559
# Epoch 160 | Loss 4.5498
# Epoch 170 | Loss 4.0944
# Epoch 180 | Loss 3.6847
# Epoch 190 | Loss 3.3161
# Epoch 200 | Loss 2.9845
# Epoch 210 | Loss 2.6861
# Epoch 220 | Loss 2.4177
# Epoch 230 | Loss 2.1762
# Epoch 240 | Loss 1.9589
# Epoch 250 | Loss 1.7634
# Epoch 260 | Loss 1.5875
# Epoch 270 | Loss 1.4293
# Epoch 280 | Loss 1.2869
# Epoch 290 | Loss 1.1588
# Epoch 300 | Loss 1.0436
# Epoch 310 | Loss 0.9399
# Epoch 320 | Loss 0.8466
# Epoch 330 | Loss 0.7627
# Epoch 340 | Loss 0.6872
# Epoch 350 | Loss 0.6192
# Epoch 360 | Loss 0.5581
# Epoch 370 | Loss 0.5031
# ...
