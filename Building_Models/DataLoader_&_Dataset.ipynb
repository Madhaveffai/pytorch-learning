# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhaveffai/pytorch-learning/blob/main/week2/DataLoader_%26_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TensorDataset

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

X = torch.linspace(0, 1, 100).unsqueeze(1)
y = 3 * X + 2 + 0.1 * torch.randn(100, 1)

dataset = TensorDataset(X, y)
print(len(dataset))
print(dataset[0])
# Out:
# 100
# (tensor([0.]), tensor([2.0463]))

# %% [markdown]
# Wrap it in a DataLoader

# %%
loader = DataLoader(dataset, batch_size=16, shuffle=True)

for X_batch, y_batch in loader:
  print(X_batch.shape, y_batch.shape)
  break
# Out:
# torch.Size([16, 1]) torch.Size([16, 1])

# %% [markdown]
# Using in training Loop

# %%
import torch.nn as nn
model = nn.Sequential(nn.Linear(1, 1))
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

for epoch in range(20):
  for X_batch, y_batch in loader:
    y_pred = model(X_batch)
    loss = loss_fn(y_pred, y_batch)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  print(f"Epoch {epoch} | Loss: {loss.item():.4f}")
# Out:
# Epoch 0 | Loss: 14.3935
# Epoch 1 | Loss: 14.5169
# Epoch 2 | Loss: 11.8592
# Epoch 3 | Loss: 9.2904
# Epoch 4 | Loss: 11.9523
# Epoch 5 | Loss: 8.5038
# Epoch 6 | Loss: 8.8744
# Epoch 7 | Loss: 10.5904
# Epoch 8 | Loss: 7.7450
# Epoch 9 | Loss: 10.4137
# Epoch 10 | Loss: 8.9118
# Epoch 11 | Loss: 7.2267
# Epoch 12 | Loss: 5.2470
# Epoch 13 | Loss: 5.1085
# Epoch 14 | Loss: 5.6295
# Epoch 15 | Loss: 4.3282
# Epoch 16 | Loss: 4.5765
# Epoch 17 | Loss: 3.2801
# Epoch 18 | Loss: 3.1500
# Epoch 19 | Loss: 4.3022

# %% [markdown]
# Train/Val Split

# %%
from torch.utils.data import random_split

train_set, val_set = random_split(dataset, [80, 20])

train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
val_loader = DataLoader(val_set, batch_size=20, shuffle=False)

print(len(train_set), len(val_set))
# Out:
# 80 20

# %% [markdown]
# create a dataset of 200 samples, split 80/20, and print how many batches your train loader has with batch_size=32.

# %%
X = torch.linspace(0, 1, 100).unsqueeze(1)
y = 3 * X + 2 + 0.1 * torch.randn(100, 1)

dataset = TensorDataset(X, y)

train_set, val_set = random_split(dataset, [80, 20])

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)


print(len(train_loader), len(val_loader))
# Out:
# 3 1
